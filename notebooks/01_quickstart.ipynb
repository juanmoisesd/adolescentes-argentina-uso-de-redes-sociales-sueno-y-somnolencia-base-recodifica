# %% [markdown]
# # Quickstart Guide
#
# Welcome to the quickstart notebook for the Adolescentes Argentina dataset.

# %%
import pandas as pd
import json

# Load schema
with open('../schema.json') as f:
    schema = json.load(f)
print(f"Dataset Title: {schema['title']}")
